# %% [markdown]
# # Chapter 2

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# 1. We’ve seen that n = 42 is legal. What about 42 = n?

# %%
42 = n
# Out:
#   Cell In[12], line 1
#     42 = n
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %% [markdown]
# That is not legal.

# %% [markdown]
# 2. How about x = y = 1?

# %%
x = y = 1
print(x)
print(y)
# Out:
# 1
# 1

# %% [markdown]
# Both x and y are assigned the value 1.

# %% [markdown]
# 3. In some languages every statement ends with a semi-colon, ;. What happens if you put a semi-colon at the end of a Python statement?

# %%
a = "hello";
b = 123;
print(a);
print(b)
# Out:
# hello
# 123

# %% [markdown]
# I don't think adding a semicolon at the end of a Python statement has much of an impact.

# %% [markdown]
# 4. What if you put a period at the end of a statement?

# %%
a = "hello".
b = 123.
print(a).
print(b)
# Out:
#   Cell In[15], line 1
#     a = "hello".
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# This will obviously cause an error; Python will recognize the presence of a dot (.).

# %% [markdown]
# 5. In math notation you can multiply x and y like this: x y. What happens if you try that in Python?

# %%
x = 5
y = 2
print(x y)
print(x * y)
# Out:
#   Cell In[16], line 3
#     print(x y)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
i = xy
print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 i = xy
#       2 print(i)
#
# NameError: name 'xy' is not defined

# %% [markdown]
# Clearly, x multiplied by y cannot be expressed in the form of x y.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# 1. The volume of a sphere with radius r is 4/3 π $r^3$. What is the volume of a sphere with radius 5?

# %%
import math
r = 5
v = 4/3 * math.pi * r**3
print(v)
# Out:
# 523.5987755982989

# %% [markdown]
# 2. Suppose the cover price of a book is $24.95 , but bookstores get a 40% discount. Shipping costs $3 for the first copy and 75 cents for each additional copy. What is the total wholesale cost for 60 copies?

# %%
cost_price = 24.95
discount = 0.4
ship_cost = 3
copies = 60
ship_add = 0.75

book_price = cost_price * (1-discount) * copies
shipping_cost = ship_cost + (copies - 1) * ship_add
total_cost = book_price + shipping_cost

print(total_cost)
# Out:
# 945.4499999999999

# %% [markdown]
# 3. If I leave my house at 6:52 am and run 1 mile at an easy pace (8:15 per mile), then 3 miles at tempo (7:12 per mile) and 1 mile at easy pace again, what time do I get home for breakfast?

# %%
from datetime import datetime, timedelta

start_time = datetime.strptime("06:52", "%H:%M")
easy_pace = timedelta(minutes=8, seconds=15)
tempo_pace = timedelta(minutes=7, seconds=12)\

total_time = easy_pace * 2 + tempo_pace * 3

finish_time = start_time + total_time

finish_time.strftime("%H:%M:%S")
# Out:
# '07:30:06'

# %% [markdown]
# # Chapter 8

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Read the documentation of the string methods at http://docs.python.org/3/library/stdtypes.html#string-methods. You might want to experiment with some of them to make sure you understand how they work. strip and replace are particularly useful.
#
# The documentation uses a syntax that might be confusing. For example, in find(sub[, start[, end]]), the brackets indicate optional arguments. So sub is required, but start is optional, and if you include start, then end is optional.

# %%
text = "   Hello, world!   "

text.strip()
# Out:
# 'Hello, world!'

# %%
sentence = "I like apples"

sentence.replace("apples", "bananas")
# Out:
# 'I like bananas'

# %%
sentence.replace("a", "A", 1)
# Out:
# 'I like Apples'

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# There is a string method called count that is similar to the function in Section 8.7. Read the documentation of this method and write an invocation that counts the number of a’s in 'banana'.

# %%
s = "banana"
s.count("a")
# Out:
# 3

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# A string slice can take a third index that specifies the “step size”; that is, the number of spaces between successive characters. A step size of 2 means every other character; 3 means every third, etc.

# %%
fruit = 'banana'
fruit[0:5:2]
# Out:
# 'bnn'

# %% [markdown]
# A step size of -1 goes through the word backwards, so the slice [::-1] generates a reversed string.

# %% [markdown]
# Use this idiom to write a one-line version of is_palindrome from Exercise 3.

# %%
def is_palindrome(s):
    return s == s[::-1]

# %%
print(is_palindrome("level"))
print(is_palindrome("reader"))
# Out:
# True
# False

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# The following functions are all intended to check whether a string contains any lowercase letters, but at least some of them are wrong. For each function, describe what the function actually does (assuming that the parameter is a string).

# %%
def any_lowercase1(s):
    for c in s:
        if c.islower():
            return True
        else:
            return False

# %% [markdown]
# Only check if the first character is lowercase.

# %%
def any_lowercase2(s):
    for c in s:
        if 'c'.islower():
            return 'True'
        else:
            return 'False'

# %% [markdown]
# Always returns "True"

# %%
def any_lowercase3(s):
    for c in s:
        flag = c.islower()
    return flag

# %% [markdown]
# Only check if the last character is lowercase.

# %%
def any_lowercase4(s):
    flag = False
    for c in s:
        flag = flag or c.islower()
    return flag

# %% [markdown]
# Used to check if a string contains at least one lowercase character.

# %%
def any_lowercase5(s):
    for c in s:
        if not c.islower():
            return False
    return True

# %% [markdown]
# Used to check if all characters are lowercase.

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# A Caesar cypher is a weak form of encryption that involves “rotating” each letter by a fixed number of places. To rotate a letter means to shift it through the alphabet, wrapping around to the beginning if necessary, so ’A’ rotated by 3 is ’D’ and ’Z’ rotated by 1 is ’A’.

# %% [markdown]
# To rotate a word, rotate each letter by the same amount. For example, “cheer” rotated by 7 is “jolly” and “melon” rotated by -10 is “cubed”. In the movie 2001: A Space Odyssey, the ship computer is called HAL, which is IBM rotated by -1.

# %% [markdown]
# Write a function called rotate_word that takes a string and an integer as parameters, and returns a new string that contains the letters from the original string rotated by the given amount.

# %% [markdown]
# You might want to use the built-in function ord, which converts a character to a numeric code, and chr, which converts numeric codes to characters. Letters of the alphabet are encoded in alphabetical order, so for example:

# %%
ord('c') - ord('a')
# Out:
# 2

# %% [markdown]
# Because 'c' is the two-eth letter of the alphabet. But beware: the numeric codes for upper case letters are different.

# %%
def rotate_word(word, shift):
    result = ""
    
    for c in word:
        if c.islower():
            start = ord('a')
            rotated = (ord(c) - start + shift) % 26 + start
            result += chr(rotated)
        elif c.isupper():
            start = ord('A')
            rotated = (ord(c) - start + shift) % 26 + start
            result += chr(rotated)
        else:
            result += c  # non-letter characters unchanged
            
    return result

# %%
rotate_word("cheer", 7)
# Out:
# 'jolly'

# %%
rotate_word("melon", -10)
# Out:
# 'cubed'

# %%
rotate_word("IBM", -1)
# Out:
# 'HAL'
